# %%
import turtle

turtle.forward(100)
turtle.left(90)
turtle.forward(200)
turtle.left(90)
turtle.forward(100)
turtle.left(90)

turtle.forward()


turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 13
#       8 turtle.left(90)
#      10 turtle.forward(200)
# ---> 13 turtle.exitonclick()
#
# File <string>:8, in exitonclick()
#
# File /usr/lib/python3.12/turtle.py:3857, in _Screen.exitonclick(self)
#    3855     return
#    3856 try:
# -> 3857     mainloop()
#    3858 except AttributeError:
#    3859     exit(0)
#
# File <string>:8, in mainloop()
#
# File /usr/lib/python3.12/turtle.py:803, in TurtleScreenBase.mainloop(self)
#     790 def mainloop(self):
#     791     """Starts event loop - calling Tkinter's mainloop function.
#     792
#     793     No argument.
#    (...)    801
#     802     """
# --> 803     self.cv.tk.mainloop()
#
# KeyboardInterrupt:
